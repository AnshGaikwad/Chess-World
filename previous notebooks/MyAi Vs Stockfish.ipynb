# %%
import chess
import chess.svg
import chess.polyglot
from IPython.display import SVG
import chess.pgn
import datetime
import chess.engine

board = chess.Board()
SVG(chess.svg.board(board=board, size=400))

pawntable = [
    0, 0, 0, 0, 0, 0, 0, 0,
    5, 10, 10, -20, -20, 10, 10, 5,
    5, -5, -10, 0, 0, -10, -5, 5,
    0, 0, 0, 20, 20, 0, 0, 0,
    5, 5, 10, 25, 25, 10, 5, 5,
    10, 10, 20, 30, 30, 20, 10, 10,
    50, 50, 50, 50, 50, 50, 50, 50,
    0, 0, 0, 0, 0, 0, 0, 0]

knightstable = [
    -50, -40, -30, -30, -30, -30, -40, -50,
    -40, -20, 0, 5, 5, 0, -20, -40,
    -30, 5, 10, 15, 15, 10, 5, -30,
    -30, 0, 15, 20, 20, 15, 0, -30,
    -30, 5, 15, 20, 20, 15, 5, -30,
    -30, 0, 10, 15, 15, 10, 0, -30,
    -40, -20, 0, 0, 0, 0, -20, -40,
    -50, -40, -30, -30, -30, -30, -40, -50]

bishopstable = [
    -20, -10, -10, -10, -10, -10, -10, -20,
    -10, 5, 0, 0, 0, 0, 5, -10,
    -10, 10, 10, 10, 10, 10, 10, -10,
    -10, 0, 10, 10, 10, 10, 0, -10,
    -10, 5, 5, 10, 10, 5, 5, -10,
    -10, 0, 5, 10, 10, 5, 0, -10,
    -10, 0, 0, 0, 0, 0, 0, -10,
    -20, -10, -10, -10, -10, -10, -10, -20]

rookstable = [
    0, 0, 0, 5, 5, 0, 0, 0,
    -5, 0, 0, 0, 0, 0, 0, -5,
    -5, 0, 0, 0, 0, 0, 0, -5,
    -5, 0, 0, 0, 0, 0, 0, -5,
    -5, 0, 0, 0, 0, 0, 0, -5,
    -5, 0, 0, 0, 0, 0, 0, -5,
    5, 10, 10, 10, 10, 10, 10, 5,
    0, 0, 0, 0, 0, 0, 0, 0]

queenstable = [
    -20, -10, -10, -5, -5, -10, -10, -20,
    -10, 0, 0, 0, 0, 0, 0, -10,
    -10, 5, 5, 5, 5, 5, 0, -10,
    0, 0, 5, 5, 5, 5, 0, -5,
    -5, 0, 5, 5, 5, 5, 0, -5,
    -10, 0, 5, 5, 5, 5, 0, -10,
    -10, 0, 0, 0, 0, 0, 0, -10,
    -20, -10, -10, -5, -5, -10, -10, -20]

kingstable = [
    20, 30, 10, 0, 0, 10, 30, 20,
    20, 20, 0, 0, 0, 0, 20, 20,
    -10, -20, -20, -20, -20, -20, -20, -10,
    -20, -30, -30, -40, -40, -30, -30, -20,
    -30, -40, -40, -50, -50, -40, -40, -30,
    -30, -40, -40, -50, -50, -40, -40, -30,
    -30, -40, -40, -50, -50, -40, -40, -30,
    -30, -40, -40, -50, -50, -40, -40, -30]


def evaluate_board():
    if board.is_checkmate():
        if board.turn:
            return -9999
        else:
            return 9999
    if board.is_stalemate():
        return 0
    if board.is_insufficient_material():
        return 0

    wp = len(board.pieces(chess.PAWN, chess.WHITE))
    bp = len(board.pieces(chess.PAWN, chess.BLACK))
    wn = len(board.pieces(chess.KNIGHT, chess.WHITE))
    bn = len(board.pieces(chess.KNIGHT, chess.BLACK))
    wb = len(board.pieces(chess.BISHOP, chess.WHITE))
    bb = len(board.pieces(chess.BISHOP, chess.BLACK))
    wr = len(board.pieces(chess.ROOK, chess.WHITE))
    br = len(board.pieces(chess.ROOK, chess.BLACK))
    wq = len(board.pieces(chess.QUEEN, chess.WHITE))
    bq = len(board.pieces(chess.QUEEN, chess.BLACK))

    material = 100 * (wp - bp) + 320 * (wn - bn) + 330 * (wb - bb) + 500 * (wr - br) + 900 * (wq - bq)

    pawnsq = sum([pawntable[i] for i in board.pieces(chess.PAWN, chess.WHITE)])
    pawnsq = pawnsq + sum([-pawntable[chess.square_mirror(i)]
                           for i in board.pieces(chess.PAWN, chess.BLACK)])
    knightsq = sum([knightstable[i] for i in board.pieces(chess.KNIGHT, chess.WHITE)])
    knightsq = knightsq + sum([-knightstable[chess.square_mirror(i)]
                               for i in board.pieces(chess.KNIGHT, chess.BLACK)])
    bishopsq = sum([bishopstable[i] for i in board.pieces(chess.BISHOP, chess.WHITE)])
    bishopsq = bishopsq + sum([-bishopstable[chess.square_mirror(i)]
                               for i in board.pieces(chess.BISHOP, chess.BLACK)])
    rooksq = sum([rookstable[i] for i in board.pieces(chess.ROOK, chess.WHITE)])
    rooksq = rooksq + sum([-rookstable[chess.square_mirror(i)]
                           for i in board.pieces(chess.ROOK, chess.BLACK)])
    queensq = sum([queenstable[i] for i in board.pieces(chess.QUEEN, chess.WHITE)])
    queensq = queensq + sum([-queenstable[chess.square_mirror(i)]
                             for i in board.pieces(chess.QUEEN, chess.BLACK)])
    kingsq = sum([kingstable[i] for i in board.pieces(chess.KING, chess.WHITE)])
    kingsq = kingsq + sum([-kingstable[chess.square_mirror(i)]
                           for i in board.pieces(chess.KING, chess.BLACK)])

    eval = material + pawnsq + knightsq + bishopsq + rooksq + queensq + kingsq
    if board.turn:
        return eval
    else:
        return -eval


def alphabeta(alpha, beta, depthleft):
    bestscore = -9999
    if (depthleft == 0):
        return quiesce(alpha, beta)
    for move in board.legal_moves:
        board.push(move)
        score = -alphabeta(-beta, -alpha, depthleft - 1)
        board.pop()
        if (score >= beta):
            return score
        if (score > bestscore):
            bestscore = score
        if (score > alpha):
            alpha = score
    return bestscore

def quiesce( alpha, beta ):
    stand_pat = evaluate_board()
    if( stand_pat >= beta ):
        return beta
    if( alpha < stand_pat ):
        alpha = stand_pat

    for move in board.legal_moves:
        if board.is_capture(move):
            board.push(move)
            score = -quiesce( -beta, -alpha )
            board.pop()

            if( score >= beta ):
                return beta
            if( score > alpha ):
                alpha = score
    return alpha

def selectmove(depth):
    try:
        move = chess.polyglot.MemoryMappedReader("C:/Users/Ansh Gaikwad/PycharmProjects/ChessWorld/books/varied.bin").weighted_choice(board).move()
        movehistory.append(move)
        return move
    except:
        bestMove = chess.Move.null()
        bestValue = -99999
        alpha = -100000
        beta = 100000
        for move in board.legal_moves:
            board.push(move)
            boardValue = -alphabeta(-beta, -alpha, depth-1)
            if boardValue > bestValue:
                bestValue = boardValue;
                bestMove = move
            if( boardValue > alpha ):
                alpha = boardValue
            board.pop()
        movehistory.append(bestMove)
        return bestMove

if __name__ == "__main__":
    engine = chess.engine.SimpleEngine.popen_uci("C:/Users/Ansh Gaikwad/PycharmProjects/ChessWorld/engine/stockfish.exe")

    count = 0

    movehistory = []
    game = chess.pgn.Game()
    game.headers["Event"] = "Example"
    game.headers["Site"] = "Linz"
    game.headers["Date"] = str(datetime.datetime.now().date())
    game.headers["Round"] = 1
    game.headers["White"] = "Stockfish11"
    game.headers["Black"] = "MyAi"
    board = chess.Board()
    while not board.is_game_over(claim_draw=True):
        if board.turn:
            count += 1
            print(f'{count}]')
            print()
            move = engine.play(board, chess.engine.Limit(time=0.1))
            movehistory.append(move.move)
            board.push(move.move)
            print(board)
            print()
        else:
            move = selectmove(3)
            board.push(move)
            print(board)
            print()


    game.add_line(movehistory)

    game.headers["Result"] = str(board.result(claim_draw=True))

    print(game)
    print(game, file=open("test.pgn", "w"), end="\n\n")


    SVG(chess.svg.board(board=board, size=400))
# Out:
# 1]
#
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
# r n b q k b . r
# p p p p p p p p
# . . . . . n . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
# 2]
#
# r n b q k b . r
# p p p p p p p p
# . . . . . n . .
# . . . . P . . .
# . . . . . . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
# r n b q k b . r
# p p p p p p p p
# . . . . . . . .
# . . . . P . . .
# . . . . n . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
# 3]
#
# r n b q k b . r
# p p p p p p p p
# . . . . . . . .
# . . . . P . . .
# . . . . n . . .
# . . . P . . . .
# P P P . . P P P
# R N B Q K B N R
#
# r n b q k b . r
# p p p p p p p p
# . . . . . . . .
# . . n . P . . .
# . . . . . . . .
# . . . P . . . .
# P P P . . P P P
# R N B Q K B N R
#
# 4]
#
# r n b q k b . r
# p p p p p p p p
# . . . . . . . .
# . . n . P . . .
# . . . P . . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
# r n b q k b . r
# p p p p p p p p
# . . . . n . . .
# . . . . P . . .
# . . . P . . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
# 5]
#
# r n b q k b . r
# p p p p p p p p
# . . . . n . . .
# . . . P P . . .
# . . . . . . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
# r n b q k b . r
# p p p p p p p p
# . . . . . . . .
# . . n P P . . .
# . . . . . . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
# 6]
#
# r n b q k b . r
# p p p p p p p p
# . . . . . . . .
# . . n P P . . .
# . . . . . . . .
# . . N . . . . .
# P P P . . P P P
# R . B Q K B N R
#
# r n b q k b . r
# p p p . p p p p
# . . . p . . . .
# . . n P P . . .
# . . . . . . . .
# . . N . . . . .
# P P P . . P P P
# R . B Q K B N R
#
# 7]
#
# r n b q k b . r
# p p p . p p p p
# . . . P . . . .
# . . n P . . . .
# . . . . . . . .
# . . N . . . . .
# P P P . . P P P
# R . B Q K B N R
#
# r n b q k b . r
# p p p . . p p p
# . . . p . . . .
# . . n P . . . .
# . . . . . . . .
# . . N . . . . .
# P P P . . P P P
# R . B Q K B N R
#
# 8]
#
# r n b q k b . r
# p p p . . p p p
# . . . p . . . .
# . . n P . . . .
# . . . . . . . .
# . . N . . N . .
# P P P . . P P P
# R . B Q K B . R
#
# r . b q k b . r
# p p p n . p p p
# . . . p . . . .
# . . n P . . . .
# . . . . . . . .
# . . N . . N . .
# P P P . . P P P
# R . B Q K B . R
#
# 9]
#
# r . b q k b . r
# p p p n . p p p
# . . . p . . . .
# . . n P . . . .
# . P . . . . . .
# . . N . . N . .
# P . P . . P P P
# R . B Q K B . R
#
# r . b . k b . r
# p p p n . p p p
# . . . p . q . .
# . . n P . . . .
# . P . . . . . .
# . . N . . N . .
# P . P . . P P P
# R . B Q K B . R
#
# 10]
#
# r . b . k b . r
# p p p n . p p p
# . . . p . q . .
# . . n P . . . .
# . P . N . . . .
# . . N . . . . .
# P . P . . P P P
# R . B Q K B . R
#
# r . b . k b . r
# p p p n q p p p
# . . . p . . . .
# . . n P . . . .
# . P . N . . . .
# . . N . . . . .
# P . P . . P P P
# R . B Q K B . R
#
# 11]
#
# r . b . k b . r
# p p p n q p p p
# . . . p . . . .
# . . n P . . . .
# . P . N . . . .
# . . N . . . . .
# P . P . B P P P
# R . B Q K . . R
#
# r . b . k b . r
# p p p n q p p p
# . . . p . . . .
# . . . P . . . .
# . P . N n . . .
# . . N . . . . .
# P . P . B P P P
# R . B Q K . . R
#
# 12]
#
# r . b . k b . r
# p p p n q p p p
# . . . p . . . .
# . . . P . . . .
# . P . N N . . .
# . . . . . . . .
# P . P . B P P P
# R . B Q K . . R
#
# r . b . k b . r
# p p p n . p p p
# . . . p . . . .
# . . . P . . . .
# . P . N q . . .
# . . . . . . . .
# P . P . B P P P
# R . B Q K . . R
#
# 13]
#
# r . b . k b . r
# p p p n . p p p
# . . . p . . . .
# . . . P . . . .
# . P . N q . . .
# . . . . . . . .
# P . P . B P P P
# R . B Q . R K .
#
# r . b . k b . r
# p p p n . p p p
# . . . p . . . .
# . . . q . . . .
# . P . N . . . .
# . . . . . . . .
# P . P . B P P P
# R . B Q . R K .
#
# 14]
#
# r . b . k b . r
# p p p n . p p p
# . . . p . . . .
# . . . q . . . .
# . P . N . . . .
# . . . . . . . .
# P . P . B P P P
# R . B Q R . K .
#
# r . b . k b . r
# p p p . . p p p
# . . . p . . . .
# . . . q n . . .
# . P . N . . . .
# . . . . . . . .
# P . P . B P P P
# R . B Q R . K .
#
# 15]
#
# r . b . k b . r
# p p p . . p p p
# . . . p . . . .
# . B . q n . . .
# . P . N . . . .
# . . . . . . . .
# P . P . . P P P
# R . B Q R . K .
#
# r . b k . b . r
# p p p . . p p p
# . . . p . . . .
# . B . q n . . .
# . P . N . . . .
# . . . . . . . .
# P . P . . P P P
# R . B Q R . K .
#
# 16]
#
# r . b k . b . r
# p p p . . p p p
# . . . p . . . .
# . B . q n . . .
# . P P N . . . .
# . . . . . . . .
# P . . . . P P P
# R . B Q R . K .
#
# r . b k . b . r
# p p p . . p p p
# . . . p . . . .
# . B . q . . . .
# . P P N . . . .
# . . . . . n . .
# P . . . . P P P
# R . B Q R . K .
#
# 17]
#
# r . b k . b . r
# p p p . . p p p
# . . . p . . . .
# . B . q . . . .
# . P P N . . . .
# . . . . . Q . .
# P . . . . P P P
# R . B . R . K .
#
# r . b k . b . r
# p p p . . p p p
# . . . p . . . .
# . B . . q . . .
# . P P N . . . .
# . . . . . Q . .
# P . . . . P P P
# R . B . R . K .
#
# 18]
#
# r . b k . b . r
# p p p . . p p p
# . . . p . . . .
# . B . . R . . .
# . P P N . . . .
# . . . . . Q . .
# P . . . . P P P
# R . B . . . K .
#
# r . b k . b . r
# p p p . . p p p
# . . . . . . . .
# . B . . p . . .
# . P P N . . . .
# . . . . . Q . .
# P . . . . P P P
# R . B . . . K .
#
# 19]
#
# r . b k . b . r
# p p p . . Q p p
# . . . . . . . .
# . B . . p . . .
# . P P N . . . .
# . . . . . . . .
# P . . . . P P P
# R . B . . . K .
#
# r . b k . . . r
# p p p . b Q p p
# . . . . . . . .
# . B . . p . . .
# . P P N . . . .
# . . . . . . . .
# P . . . . P P P
# R . B . . . K .
#
# 20]
#
# r . b k . . . r
# p p p . b . p p
# . . . . . . . .
# . B . Q p . . .
# . P P N . . . .
# . . . . . . . .
# P . . . . P P P
# R . B . . . K .
#
# r . . k . . . r
# p p p b b . p p
# . . . . . . . .
# . B . Q p . . .
# . P P N . . . .
# . . . . . . . .
# P . . . . P P P
# R . B . . . K .
#
# 21]
#
# r . . k . . . r
# p p p Q b . p p
# . . . . . . . .
# . B . . p . . .
# . P P N . . . .
# . . . . . . . .
# P . . . . P P P
# R . B . . . K .
#
# [Event "Example"]
# [Site "Linz"]
# [Date "2020-05-07"]
# [Round "1"]
# [White "Stockfish11"]
# [Black "MyAi"]
# [Result "1-0"]
#
# 1. e4 Nf6 2. e5 Ne4 3. d3 Nc5 4. d4 Ne6 5. d5 Nc5 6. Nc3 d6 7. exd6 exd6 8. Nf3 Nbd7 9. b4 Qf6 10. Nd4 Qe7+ 11. Be2 Ne4 12. Nxe4 Qxe4 13. O-O Qxd5 14. Re1 Ne5 15. Bb5+ Kd8 16. c4 Nf3+ 17. Qxf3 Qe5 18. Rxe5 dxe5 19. Qxf7 Be7 20. Qd5+ Bd7 21. Qxd7# 1-0

# %%
import chess
import chess.svg
import chess.polyglot
from IPython.display import SVG
import chess.pgn
import datetime
import chess.engine

board = chess.Board()
SVG(chess.svg.board(board=board, size=400))

pawntable = [
    0, 0, 0, 0, 0, 0, 0, 0,
    5, 10, 10, -20, -20, 10, 10, 5,
    5, -5, -10, 0, 0, -10, -5, 5,
    0, 0, 0, 20, 20, 0, 0, 0,
    5, 5, 10, 25, 25, 10, 5, 5,
    10, 10, 20, 30, 30, 20, 10, 10,
    50, 50, 50, 50, 50, 50, 50, 50,
    0, 0, 0, 0, 0, 0, 0, 0]

knightstable = [
    -50, -40, -30, -30, -30, -30, -40, -50,
    -40, -20, 0, 5, 5, 0, -20, -40,
    -30, 5, 10, 15, 15, 10, 5, -30,
    -30, 0, 15, 20, 20, 15, 0, -30,
    -30, 5, 15, 20, 20, 15, 5, -30,
    -30, 0, 10, 15, 15, 10, 0, -30,
    -40, -20, 0, 0, 0, 0, -20, -40,
    -50, -40, -30, -30, -30, -30, -40, -50]

bishopstable = [
    -20, -10, -10, -10, -10, -10, -10, -20,
    -10, 5, 0, 0, 0, 0, 5, -10,
    -10, 10, 10, 10, 10, 10, 10, -10,
    -10, 0, 10, 10, 10, 10, 0, -10,
    -10, 5, 5, 10, 10, 5, 5, -10,
    -10, 0, 5, 10, 10, 5, 0, -10,
    -10, 0, 0, 0, 0, 0, 0, -10,
    -20, -10, -10, -10, -10, -10, -10, -20]

rookstable = [
    0, 0, 0, 5, 5, 0, 0, 0,
    -5, 0, 0, 0, 0, 0, 0, -5,
    -5, 0, 0, 0, 0, 0, 0, -5,
    -5, 0, 0, 0, 0, 0, 0, -5,
    -5, 0, 0, 0, 0, 0, 0, -5,
    -5, 0, 0, 0, 0, 0, 0, -5,
    5, 10, 10, 10, 10, 10, 10, 5,
    0, 0, 0, 0, 0, 0, 0, 0]

queenstable = [
    -20, -10, -10, -5, -5, -10, -10, -20,
    -10, 0, 0, 0, 0, 0, 0, -10,
    -10, 5, 5, 5, 5, 5, 0, -10,
    0, 0, 5, 5, 5, 5, 0, -5,
    -5, 0, 5, 5, 5, 5, 0, -5,
    -10, 0, 5, 5, 5, 5, 0, -10,
    -10, 0, 0, 0, 0, 0, 0, -10,
    -20, -10, -10, -5, -5, -10, -10, -20]

kingstable = [
    20, 30, 10, 0, 0, 10, 30, 20,
    20, 20, 0, 0, 0, 0, 20, 20,
    -10, -20, -20, -20, -20, -20, -20, -10,
    -20, -30, -30, -40, -40, -30, -30, -20,
    -30, -40, -40, -50, -50, -40, -40, -30,
    -30, -40, -40, -50, -50, -40, -40, -30,
    -30, -40, -40, -50, -50, -40, -40, -30,
    -30, -40, -40, -50, -50, -40, -40, -30]


def evaluate_board():
    if board.is_checkmate():
        if board.turn:
            return -9999
        else:
            return 9999
    if board.is_stalemate():
        return 0
    if board.is_insufficient_material():
        return 0

    wp = len(board.pieces(chess.PAWN, chess.WHITE))
    bp = len(board.pieces(chess.PAWN, chess.BLACK))
    wn = len(board.pieces(chess.KNIGHT, chess.WHITE))
    bn = len(board.pieces(chess.KNIGHT, chess.BLACK))
    wb = len(board.pieces(chess.BISHOP, chess.WHITE))
    bb = len(board.pieces(chess.BISHOP, chess.BLACK))
    wr = len(board.pieces(chess.ROOK, chess.WHITE))
    br = len(board.pieces(chess.ROOK, chess.BLACK))
    wq = len(board.pieces(chess.QUEEN, chess.WHITE))
    bq = len(board.pieces(chess.QUEEN, chess.BLACK))

    material = 100 * (wp - bp) + 320 * (wn - bn) + 330 * (wb - bb) + 500 * (wr - br) + 900 * (wq - bq)

    pawnsq = sum([pawntable[i] for i in board.pieces(chess.PAWN, chess.WHITE)])
    pawnsq = pawnsq + sum([-pawntable[chess.square_mirror(i)]
                           for i in board.pieces(chess.PAWN, chess.BLACK)])
    knightsq = sum([knightstable[i] for i in board.pieces(chess.KNIGHT, chess.WHITE)])
    knightsq = knightsq + sum([-knightstable[chess.square_mirror(i)]
                               for i in board.pieces(chess.KNIGHT, chess.BLACK)])
    bishopsq = sum([bishopstable[i] for i in board.pieces(chess.BISHOP, chess.WHITE)])
    bishopsq = bishopsq + sum([-bishopstable[chess.square_mirror(i)]
                               for i in board.pieces(chess.BISHOP, chess.BLACK)])
    rooksq = sum([rookstable[i] for i in board.pieces(chess.ROOK, chess.WHITE)])
    rooksq = rooksq + sum([-rookstable[chess.square_mirror(i)]
                           for i in board.pieces(chess.ROOK, chess.BLACK)])
    queensq = sum([queenstable[i] for i in board.pieces(chess.QUEEN, chess.WHITE)])
    queensq = queensq + sum([-queenstable[chess.square_mirror(i)]
                             for i in board.pieces(chess.QUEEN, chess.BLACK)])
    kingsq = sum([kingstable[i] for i in board.pieces(chess.KING, chess.WHITE)])
    kingsq = kingsq + sum([-kingstable[chess.square_mirror(i)]
                           for i in board.pieces(chess.KING, chess.BLACK)])

    eval = material + pawnsq + knightsq + bishopsq + rooksq + queensq + kingsq
    if board.turn:
        return eval
    else:
        return -eval


def alphabeta(alpha, beta, depthleft):
    bestscore = -9999
    if (depthleft == 0):
        return quiesce(alpha, beta)
    for move in board.legal_moves:
        board.push(move)
        score = -alphabeta(-beta, -alpha, depthleft - 1)
        board.pop()
        if (score >= beta):
            return score
        if (score > bestscore):
            bestscore = score
        if (score > alpha):
            alpha = score
    return bestscore

def quiesce( alpha, beta ):
    stand_pat = evaluate_board()
    if( stand_pat >= beta ):
        return beta
    if( alpha < stand_pat ):
        alpha = stand_pat

    for move in board.legal_moves:
        if board.is_capture(move):
            board.push(move)
            score = -quiesce( -beta, -alpha )
            board.pop()

            if( score >= beta ):
                return beta
            if( score > alpha ):
                alpha = score
    return alpha

def selectmove(depth):
    try:
        move = chess.polyglot.MemoryMappedReader("C:/Users/Ansh Gaikwad/PycharmProjects/ChessWorld/books/varied.bin").weighted_choice(board).move()
        movehistory.append(move)
        return move
    except:
        bestMove = chess.Move.null()
        bestValue = -99999
        alpha = -100000
        beta = 100000
        for move in board.legal_moves:
            board.push(move)
            boardValue = -alphabeta(-beta, -alpha, depth-1)
            if boardValue > bestValue:
                bestValue = boardValue;
                bestMove = move
            if( boardValue > alpha ):
                alpha = boardValue
            board.pop()
        movehistory.append(bestMove)
        return bestMove

if __name__ == "__main__":
    engine = chess.engine.SimpleEngine.popen_uci("C:/Users/Ansh Gaikwad/PycharmProjects/ChessWorld/engine/stockfish.exe")

    count = 0

    movehistory = []
    game = chess.pgn.Game()
    game.headers["Event"] = "Example"
    game.headers["Site"] = "Linz"
    game.headers["Date"] = str(datetime.datetime.now().date())
    game.headers["Round"] = 1
    game.headers["White"] = "Stockfish11"
    game.headers["Black"] = "MyAi"
    board = chess.Board()
    while not board.is_game_over(claim_draw=True):
        if board.turn:
            count += 1
            print(f'{count}]')
            print()
            move = engine.play(board, chess.engine.Limit(time=0.1))
            movehistory.append(move.move)
            board.push(move.move)
            print(board)
            print()
        else:
            move = selectmove(3)
            board.push(move)
            print(board)
            print()


    game.add_line(movehistory)

    game.headers["Result"] = str(board.result(claim_draw=True))

    print(game)
    print(game, file=open("test.pgn", "w"), end="\n\n")


    SVG(chess.svg.board(board=board, size=400))
# Out:
# 1]
#
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
# r n b q k b . r
# p p p p p p p p
# . . . . . n . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
# 2]
#
# r n b q k b . r
# p p p p p p p p
# . . . . . n . .
# . . . . P . . .
# . . . . . . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
# r n b q k b . r
# p p p p p p p p
# . . . . . . . .
# . . . . P . . .
# . . . . n . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
# 3]
#
# r n b q k b . r
# p p p p p p p p
# . . . . . . . .
# . . . . P . . .
# . . . . n . . .
# . . . P . . . .
# P P P . . P P P
# R N B Q K B N R
#
# r n b q k b . r
# p p p p p p p p
# . . . . . . . .
# . . n . P . . .
# . . . . . . . .
# . . . P . . . .
# P P P . . P P P
# R N B Q K B N R
#
# 4]
#
# r n b q k b . r
# p p p p p p p p
# . . . . . . . .
# . . n . P . . .
# . . . P . . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
# r n b q k b . r
# p p p p p p p p
# . . . . n . . .
# . . . . P . . .
# . . . P . . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
# 5]
#
# r n b q k b . r
# p p p p p p p p
# . . . . n . . .
# . . . P P . . .
# . . . . . . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
# r n b q k b . r
# p p p p p p p p
# . . . . . . . .
# . . n P P . . .
# . . . . . . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
# 6]
#
# r n b q k b . r
# p p p p p p p p
# . . . . . . . .
# . . n P P . . .
# . P . . . . . .
# . . . . . . . .
# P . P . . P P P
# R N B Q K B N R
#
# r n b q k b . r
# p p p p p p p p
# n . . . . . . .
# . . . P P . . .
# . P . . . . . .
# . . . . . . . .
# P . P . . P P P
# R N B Q K B N R
#
# 7]
#
# r n b q k b . r
# p p p p p p p p
# n . . . . . . .
# . . . P P . . .
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B Q K B N R
#
# r n b q k b . r
# p p p . p p p p
# n . . p . . . .
# . . . P P . . .
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B Q K B N R
#
# 8]
#
# r n b q k b . r
# p p p . p p p p
# n . . p . . . .
# . . . P P . . .
# . P . . . . . .
# P . . . . N . .
# . . P . . P P P
# R N B Q K B . R
#
# r n b q k b . r
# p p p . p p p p
# n . . . . . . .
# . . . P p . . .
# . P . . . . . .
# P . . . . N . .
# . . P . . P P P
# R N B Q K B . R
#
# 9]
#
# r n b q k b . r
# p p p . p p p p
# n . . . . . . .
# . . . P N . . .
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B Q K B . R
#
# r . b q k b . r
# p p p n p p p p
# n . . . . . . .
# . . . P N . . .
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B Q K B . R
#
# 10]
#
# r . b q k b . r
# p p p n p p p p
# n . . . . . . .
# . B . P N . . .
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B Q K . . R
#
# r . b q k b . r
# p p . n p p p p
# n . p . . . . .
# . B . P N . . .
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B Q K . . R
#
# 11]
#
# r . b q k b . r
# p p . n p p p p
# n . P . . . . .
# . B . . N . . .
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B Q K . . R
#
# r . b q k b . r
# p . . n p p p p
# n . p . . . . .
# . B . . N . . .
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B Q K . . R
#
# 12]
#
# r . b q k b . r
# p . . n p p p p
# n . B . . . . .
# . . . . N . . .
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B Q K . . R
#
# . r b q k b . r
# p . . n p p p p
# n . B . . . . .
# . . . . N . . .
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B Q K . . R
#
# 13]
#
# . r b q k b . r
# p . . n p p p p
# n . B . . . . .
# . . . . N . . .
# . P . . . . . .
# P . . . . Q . .
# . . P . . P P P
# R N B . K . . R
#
# . r b q k b . r
# p . . n p . p p
# n . B . . . . .
# . . . . N p . .
# . P . . . . . .
# P . . . . Q . .
# . . P . . P P P
# R N B . K . . R
#
# 14]
#
# . r b q k b . r
# p . . n p . p p
# n . B . . . . .
# . . . . N p . Q
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B . K . . R
#
# . r b q k b . r
# p . . n p . . p
# n . B . . . p .
# . . . . N p . Q
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B . K . . R
#
# 15]
#
# . r b q k b . r
# p . . n p . . p
# n . B . . . N .
# . . . . . p . Q
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B . K . . R
#
# . r b q k b r .
# p . . n p . . p
# n . B . . . N .
# . . . . . p . Q
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B . K . . R
#
# 16]
#
# . r b q k b r .
# p . . n p . . p
# n . B . . . . .
# . . . . N p . Q
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B . K . . R
#
# . r b q k b . .
# p . . n p . . p
# n . B . . . r .
# . . . . N p . Q
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B . K . . R
#
# 17]
#
# . r b q k b . .
# p . . n p . . p
# n . B . . . N .
# . . . . . p . Q
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B . K . . R
#
# . r b . k b . .
# p . . n p . . p
# n q B . . . N .
# . . . . . p . Q
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B . K . . R
#
# 18]
#
# . r b . k b . .
# p . . n p . . p
# n q B . . . . .
# . . . . . p . Q
# . P . . . N . .
# P . . . . . . .
# . . P . . P P P
# R N B . K . . R
#
# . r b k . b . .
# p . . n p . . p
# n q B . . . . .
# . . . . . p . Q
# . P . . . N . .
# P . . . . . . .
# . . P . . P P P
# R N B . K . . R
#
# 19]
#
# . r b k . b . .
# p . . n p . . p
# n q B . N . . .
# . . . . . p . Q
# . P . . . . . .
# P . . . . . . .
# . . P . . P P P
# R N B . K . . R
#
# [Event "Example"]
# [Site "Linz"]
# [Date "2020-03-27"]
# [Round "1"]
# [White "Stockfish11"]
# [Black "MyAi"]
# [Result "1-0"]
#
# 1. e4 Nf6 2. e5 Ne4 3. d3 Nc5 4. d4 Ne6 5. d5 Nc5 6. b4 Nca6 7. a3 d6 8. Nf3 dxe5 9. Nxe5 Nd7 10. Bb5 c6 11. dxc6 bxc6 12. Bxc6 Rb8 13. Qf3 f5 14. Qh5+ g6 15. Nxg6 Rg8 16. Ne5+ Rg6 17. Nxg6 Qb6 18. Nf4+ Kd8 19. Ne6# 1-0
